# %% [markdown]
# ## Sub-Problem 3: Does textual data in the summary and sentiments of reviews affect price?

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
# Importing the listing dataset
listingsDF = pd.read_csv('listings.csv')
listingsDF.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                10.0
# 1  Queen Anne is a wonderful, truly functional vi...  ...                10.0
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                10.0
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1              strict                              t
# 2              strict                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Certain textual variables were extracted into a dataframe
listingDF = listingsDF[['id','name','summary','longitude','latitude','space','description','instant_bookable','neighborhood_overview','neighbourhood_cleansed','host_id','host_name','host_since',
                 'host_response_time','street', 'zipcode','review_scores_rating','property_type','room_type','accommodates','bathrooms','bedrooms','beds','reviews_per_month','amenities','cancellation_policy','number_of_reviews','price']]
listingDF.head()
# Out:
#         id                                 name  \
# 0   241032         Stylish Queen Anne Apartment
# 1   953595   Bright & Airy Queen Anne Apartment
# 2  3308979  New Modern House-Amazing water view
# 3  7421966                   Queen Anne Chateau
# 4   278830       Charming craftsman 3 bdm house
#
#                                              summary   longitude   latitude  \
# 0                                                NaN -122.371025  47.636289
# 1  Chemically sensitive? We've removed the irrita... -122.365666  47.639123
# 2  New modern house built in 2013.  Spectacular s... -122.369483  47.629724
# 3  A charming apartment that sits atop Queen Anne... -122.369279  47.638473
# 4  Cozy family craftman house in beautiful neighb... -122.372471  47.632918
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description instant_bookable  \
# 0  Make your self at home in this charming one-be...                f
# 1  Chemically sensitive? We've removed the irrita...                f
# 2  New modern house built in 2013.  Spectacular s...                f
# 3  A charming apartment that sits atop Queen Anne...                f
# 4  Cozy family craftman house in beautiful neighb...                f
#
#                                neighborhood_overview neighbourhood_cleansed  \
# 0                                                NaN        West Queen Anne
# 1  Queen Anne is a wonderful, truly functional vi...        West Queen Anne
# 2  Upper Queen Anne is a charming neighborhood fu...        West Queen Anne
# 3                                                NaN        West Queen Anne
# 4  We are in the beautiful neighborhood of Queen ...        West Queen Anne
#
#    ...        room_type accommodates bathrooms bedrooms beds  \
# 0  ...  Entire home/apt            4       1.0      1.0  1.0
# 1  ...  Entire home/apt            4       1.0      1.0  1.0
# 2  ...  Entire home/apt           11       4.5      5.0  7.0
# 3  ...  Entire home/apt            3       1.0      0.0  2.0
# 4  ...  Entire home/apt            6       2.0      3.0  3.0
#
#   reviews_per_month                                          amenities  \
# 0              4.07  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 1              1.48  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 2              1.15  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 3               NaN  {Internet,"Wireless Internet",Kitchen,"Indoor ...
# 4              0.89  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
#
#   cancellation_policy number_of_reviews    price
# 0            moderate               207   $85.00
# 1              strict                43  $150.00
# 2              strict                20  $975.00
# 3            flexible                 0  $100.00
# 4              strict                38  $450.00
#
# [5 rows x 28 columns]

# %%
# Replace NaN values with 0
listingDF.fillna(0, inplace=True)

# Extract prices from listingDF into priceDF
priceDF = listingDF['price']
# Create an empty prices list
prices=[]

# Convert prices from listingDF into float values and append it in prices list
for p in priceDF:
    p = float(p[1:].replace(',',''))
    prices.append(p)
    
# Replace the price column in the original listingDF with the new prices
listingDF['price'] = prices

# Remove listings with 0 for  bedrooms, bathrooms, accomodates, price, beds, review_scores_rating, reviews_per_month
listingDF = listingDF[listingDF.bedrooms > 0]
listingDF = listingDF[listingDF.bathrooms > 0]
listingDF = listingDF[listingDF.accommodates > 0]
listingDF = listingDF[listingDF.price > 0]
listingDF = listingDF[listingDF.beds > 0]
listingDF = listingDF[listingDF.review_scores_rating > 0]
listingDF = listingDF[listingDF.reviews_per_month > 0]

listingDF.head()
# Out:
# C:\Users\kaush\AppData\Local\Temp\ipykernel_20368\3887564020.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingDF.fillna(0, inplace=True)
# C:\Users\kaush\AppData\Local\Temp\ipykernel_20368\3887564020.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingDF['price'] = prices
#         id                                 name  \
# 0   241032         Stylish Queen Anne Apartment
# 1   953595   Bright & Airy Queen Anne Apartment
# 2  3308979  New Modern House-Amazing water view
# 4   278830       Charming craftsman 3 bdm house
# 5  5956968      Private unit in a 1920s mansion
#
#                                              summary   longitude   latitude  \
# 0                                                  0 -122.371025  47.636289
# 1  Chemically sensitive? We've removed the irrita... -122.365666  47.639123
# 2  New modern house built in 2013.  Spectacular s... -122.369483  47.629724
# 4  Cozy family craftman house in beautiful neighb... -122.372471  47.632918
# 5  We're renting out a small private unit of one ... -122.366174  47.630525
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 4  Cozy family craftman house in beautiful neighb...
# 5  If you include a bit of your background in you...
#
#                                          description instant_bookable  \
# 0  Make your self at home in this charming one-be...                f
# 1  Chemically sensitive? We've removed the irrita...                f
# 2  New modern house built in 2013.  Spectacular s...                f
# 4  Cozy family craftman house in beautiful neighb...                f
# 5  We're renting out a small private unit of one ...                f
#
#                                neighborhood_overview neighbourhood_cleansed  \
# 0                                                  0        West Queen Anne
# 1  Queen Anne is a wonderful, truly functional vi...        West Queen Anne
# 2  Upper Queen Anne is a charming neighborhood fu...        West Queen Anne
# 4  We are in the beautiful neighborhood of Queen ...        West Queen Anne
# 5  This part of Queen Anne has wonderful views an...        West Queen Anne
#
#    ...        room_type accommodates bathrooms bedrooms beds  \
# 0  ...  Entire home/apt            4       1.0      1.0  1.0
# 1  ...  Entire home/apt            4       1.0      1.0  1.0
# 2  ...  Entire home/apt           11       4.5      5.0  7.0
# 4  ...  Entire home/apt            6       2.0      3.0  3.0
# 5  ...     Private room            2       1.0      1.0  1.0
#
#   reviews_per_month                                          amenities  \
# 0              4.07  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 1              1.48  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 2              1.15  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 4              0.89  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 5              2.45  {"Wireless Internet","Free Parking on Premises...
#
#   cancellation_policy number_of_reviews  price
# 0            moderate               207   85.0
# 1              strict                43  150.0
# 2              strict                20  975.0
# 4              strict                38  450.0
# 5              strict                17  120.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Analyzing the summaries of the most expensive listings

# %%
# Creating a dataframe of the summaries of the 100 most expensive listings
summaryDF = listingDF[['summary','price']]
summaryDF = summaryDF[pd.notnull(summaryDF['summary'])]
summaryDF = summaryDF[summaryDF['summary']!=0]
summaryDF = summaryDF.sort_values('price',ascending=[0])
top100DF = summaryDF.head(100)
top100DF.head()
# Out:
#                                                 summary   price
# 3122  2 bedroom fully finished basement apartment wi...  1000.0
# 1208  100% Walk Score close to the Convention Center...   999.0
# 2     New modern house built in 2013.  Spectacular s...   975.0
# 3443  Beautiful home that is located quiet neighborh...   950.0
# 1279  Fully updated by professional interior designe...   899.0

# %%
import nltk

# Download required NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Sample text
text = "This is a test sentence for tokenization."

# --- Step 1: Tokenize using regex (splits on non-alphabetic characters) ---
tokens = re.findall(r'\b[a-zA-Z]+\b', text)

# --- Step 2: Remove stopwords ---
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# --- Step 3: Lemmatize ---
wnl = WordNetLemmatizer()
lemmatized_tokens = [wnl.lemmatize(word) for word in filtered_tokens]

print(lemmatized_tokens)
# Out:
# ['test', 'sentence', 'tokenization']

# %%
import pandas as pd
import re
from collections import Counter

# --- Example: replace NaN with empty string ---
listingDF['amenities'] = listingDF['amenities'].fillna('')

# --- Simple text cleaning & tokenization ---
def clean_text_simple(text):
    # Keep only letters, replace everything else with space
    text = re.sub(r'[^a-zA-Z]+', ' ', str(text))
    # Convert to lowercase and split into words
    tokens = text.lower().split()
    return tokens

# Apply cleaning to the 'amenities' column
listingDF['amenities_clean'] = listingDF['amenities'].apply(lambda x: ' '.join(clean_text_simple(x)))

# Optional: combine all amenities for frequency analysis
all_amenities = ' '.join(listingDF['amenities_clean'].tolist())
all_tokens = all_amenities.split()
top_words = Counter(all_tokens).most_common(20)

print("Top 20 amenities words:", top_words)
listingDF[['amenities', 'amenities_clean']].head()
import pandas as pd
import re
from collections import Counter

# --- Example: replace NaN with empty string ---
listingDF['amenities'] = listingDF['amenities'].fillna('')

# --- Simple text cleaning & tokenization ---
def clean_text_simple(text):
    # Keep only letters, replace everything else with space
    text = re.sub(r'[^a-zA-Z]+', ' ', str(text))
    # Convert to lowercase and split into words
    tokens = text.lower().split()
    return tokens

# Apply cleaning to the 'amenities' column
listingDF['amenities_clean'] = listingDF['amenities'].apply(lambda x: ' '.join(clean_text_simple(x)))

# Optional: combine all amenities for frequency analysis
all_amenities = ' '.join(listingDF['amenities_clean'].tolist())
all_tokens = all_amenities.split()
top_words = Counter(all_tokens).most_common(20)

print("Top 20 amenities words:", top_words)
listingDF[['amenities', 'amenities_clean']].head()
# Out:
# Top 20 amenities words: [('internet', 4900), ('detector', 4390), ('wireless', 3155), ('tv', 3055), ('dryer', 2808), ('heating', 2731), ('kitchen', 2556), ('smoke', 2486), ('on', 2459), ('essentials', 2438), ('washer', 2274), ('shampoo', 2047), ('friendly', 2019), ('carbon', 1904), ('monoxide', 1904), ('free', 1710), ('parking', 1710), ('premises', 1710), ('fire', 1701), ('extinguisher', 1701)]
# Top 20 amenities words: [('internet', 4900), ('detector', 4390), ('wireless', 3155), ('tv', 3055), ('dryer', 2808), ('heating', 2731), ('kitchen', 2556), ('smoke', 2486), ('on', 2459), ('essentials', 2438), ('washer', 2274), ('shampoo', 2047), ('friendly', 2019), ('carbon', 1904), ('monoxide', 1904), ('free', 1710), ('parking', 1710), ('premises', 1710), ('fire', 1701), ('extinguisher', 1701)]
#                                            amenities  \
# 0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 1  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 2  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 4  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 5  {"Wireless Internet","Free Parking on Premises...
#
#                                      amenities_clean
# 0  tv cable tv internet wireless internet air con...
# 1  tv internet wireless internet kitchen free par...
# 2  tv cable tv internet wireless internet air con...
# 4  tv cable tv internet wireless internet kitchen...
# 5  wireless internet free parking on premises hea...

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kaush\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\kaush\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\kaush\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kaush\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kaush\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Combine all cleaned amenities into a single string
all_amenities = ' '.join(listingDF['amenities_clean'].tolist())

# Generate the word cloud
wordcloud = WordCloud(
    width=1000,
    height=700,
    background_color="white",
    stopwords=STOPWORDS
).generate(all_amenities)

# Plot
plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# From the word cloud above, we can see that summaries of the most expensive listings all have particularly 3 words in common: 'seattle', 'home' & 'view'. Other words like: 'kitchen', 'bedroom', 'walk', 'modern' also commonly appear in those listings. But could it just be that all listings have these words in their summaries? To find out, lets also analyze the summaries of the cheapest listings and see if we can infer anything from that.

# %%
# Creating a dataframe of the summaries of the 100 most cheapest listings
summaryLowDF = listingDF[['summary','price']]
summaryLowDF = summaryLowDF[pd.notnull(summaryLowDF['summary'])]
summaryLowDF = summaryLowDF[summaryLowDF['summary']!=0]
summarLowyDF = summaryLowDF.sort_values('price',ascending=[1])
bot100DF = summaryLowDF.head(100)
bot100DF.sample(n=5)
# Out:
#                                                summary  price
# 99   We welcome you to this modern home in the hear...  134.0
# 6    Enjoy a quiet stay in our comfortable 1915 Cra...   80.0
# 96   A  cozy cottage behind a lovely Victorian hous...   89.0
# 33   Beautiful Water View, Minutes to Pier, Space N...  222.0
# 101  A perfect, private guest suite in a brand new ...   65.0

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string

# Make sure stopwords and wordnet are downloaded
nltk.download('stopwords')
nltk.download('wordnet')

# Combine all summaries into one string
words = ' '.join(bot100DF['summary'].dropna().astype(str))

# Regex tokenizer (only letters, avoids NLTK punkt)
tokens = re.findall(r'\b[a-zA-Z]+\b', words)

# Lowercase, remove stopwords
stop_words = set(stopwords.words('english'))
tokens = [w.lower() for w in tokens if w.lower() not in stop_words]

# Lemmatize
wnl = WordNetLemmatizer()
final_tokens = [wnl.lemmatize(w) for w in tokens]

# Join back into string
final_words = ' '.join(final_tokens)
print(final_words[:100])
# Out:
# chemically sensitive removed irritant triggering allergy asthma attack like carpeting forced air use
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
wordcloud = WordCloud(width = 1000, height = 700, background_color="white").generate(final_words)
plt.figure(figsize=(18,12))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Here we have seen the most common words in the summary of the cheapest listings. As it can be seen from the wordcloud, indeed there are overlapping words with the most expensive listings. Words like: 'seattle', 'bedroom', 'home' appear frequently in both. So they do not tell us anything special. However, words like: 'view', 'modern' & 'walk' appear more frequently in expensive listings as opposed to cheaper listings. So it turns out that indeed there are certain words which appear more frequently among expensive listings.

# %% [markdown]
# ### Analyzing if review sentiment has any relation with price?

# %%
reviewsDF = pd.read_csv("reviews.csv")
reviewsDF = reviewsDF.dropna()
reviewsDF.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %% [markdown]
# ###### We will use the built-in analyzer in the NLTK Python library to assign a polarity score to each comment to retrieve the 'sentiment' of comments - 'positive','negative' or 'neutral'

# %%
import nltk
# Download the VADER lexicon if not already present
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# Initialize new columns
reviewsDF['polarity_value'] = "Default"
reviewsDF['neg'] = 0.0
reviewsDF['pos'] = 0.0
reviewsDF['neu'] = 0.0
reviewsDF['compound'] = 0.0

# Iterate over rows
for index, row in reviewsDF.iterrows():
    ss = sid.polarity_scores(str(row['comments']))
    reviewsDF.at[index, 'polarity_value'] = ss
    reviewsDF.at[index, 'neg'] = ss['neg']
    reviewsDF.at[index, 'pos'] = ss['pos']
    reviewsDF.at[index, 'neu'] = ss['neu']
    reviewsDF.at[index, 'compound'] = ss['compound']

reviewsDF.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\kaush\AppData\Roaming\nltk_data...
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments  \
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...
#
#                                       polarity_value    neg    pos    neu  \
# 0  {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'comp...  0.000  0.538  0.462
# 1  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...  0.000  0.391  0.609
# 2  {'neg': 0.043, 'neu': 0.772, 'pos': 0.185, 'co...  0.043  0.185  0.772
# 3  {'neg': 0.035, 'neu': 0.765, 'pos': 0.2, 'comp...  0.035  0.200  0.765
# 4  {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'comp...  0.000  0.345  0.655
#
#    compound
# 0    0.7901
# 1    0.9872
# 2    0.8718
# 3    0.8313
# 4    0.9783

# %%
reviewsDF.to_csv('polarity_reviews.csv')

# %% [markdown]
# The polarity scores of each review for each listing is exported to the polarity_reviews.csv file. You can view the attached polarity_reviews.csv file.

# %%
pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ------------------------------------- 981.5/981.5 kB 21.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\kaush\anaconda3\lib\site-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993250 sha256=4eb989da7fed0f87c49229d4c728bb53703e8db8e7aecc809ea9a3e0536afa28
#   Stored in directory: c:\users\kaush\appdata\local\pip\cache\wheels\eb\87\25\2dddf1c94e1786054e25022ec5530bfed52bad86d882999c48
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
from langdetect import detect

# Function to detect language
def detect_lang(sente):
    sente = str(sente)
    try:
        return detect(sente)
    except:
        return "None"

# Create a new column 'language'
reviewsDF['language'] = reviewsDF['comments'].apply(detect_lang)

# Filter only English reviews
EngReviewsDF = reviewsDF[reviewsDF['language'] == 'en']

EngReviewsDF.head(2)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
#
#                                             comments  \
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
#
#                                       polarity_value  neg    pos    neu  \
# 0  {'neg': 0.0, 'neu': 0.462, 'pos': 0.538, 'comp...  0.0  0.538  0.462
# 1  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...  0.0  0.391  0.609
#
#    compound language
# 0    0.7901       en
# 1    0.9872       en

# %% [markdown]
# ##### Number of comments with positive sentiment

# %%
import numpy as np
import pandas as pd

# Group by bins
polarDF = EngReviewsDF[['pos']]
polarDF = polarDF.groupby(pd.cut(polarDF["pos"], np.arange(0, 1.1, 0.1))).count()
polarDF = polarDF.rename(columns={'pos': 'count_of_Comments'})
polarDF = polarDF.reset_index()

# Add RANGE and Sentiment columns
polarDF['RANGE'] = polarDF['pos'].apply(lambda x: round(x.left, 2) if pd.notnull(x) else 0)
polarDF['Sentiment'] = 'positive'

# Delete old column
del polarDF['pos']

polarDF.head()
# Out:
# C:\Users\kaush\AppData\Local\Temp\ipykernel_20368\3755454259.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   polarDF = polarDF.groupby(pd.cut(polarDF["pos"], np.arange(0, 1.1, 0.1))).count()
#    count_of_Comments RANGE Sentiment
# 0               1653   0.0  positive
# 1              14093   0.1  positive
# 2              29158   0.2  positive
# 3              22304   0.3  positive
# 4               9894   0.4  positive

# %% [markdown]
# ##### Number of comments with negative sentiment

# %%
import numpy as np
import pandas as pd

# Group negative sentiment into bins
polarDFneg = EngReviewsDF[['neg']]
polarDFneg = polarDFneg.groupby(pd.cut(polarDFneg["neg"], np.arange(0, 1.1, 0.1))).count()
polarDFneg = polarDFneg.rename(columns={'neg':'count_of_Comments'})
polarDFneg = polarDFneg.reset_index()

# Add RANGE and Sentiment columns
polarDFneg['RANGE'] = polarDFneg['neg'].apply(lambda x: round(x.left, 2) if pd.notnull(x) else 0)
polarDFneg['Sentiment'] = 'negative'

# Delete old column
del polarDFneg['neg']

# Combine with positive sentiment dataframe
polarDF = pd.concat([polarDF, polarDFneg], ignore_index=True)

polarDF.head()
# Out:
# C:\Users\kaush\AppData\Local\Temp\ipykernel_20368\3843429555.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   polarDFneg = polarDFneg.groupby(pd.cut(polarDFneg["neg"], np.arange(0, 1.1, 0.1))).count()
#    count_of_Comments RANGE Sentiment
# 0               1653   0.0  positive
# 1              14093   0.1  positive
# 2              29158   0.2  positive
# 3              22304   0.3  positive
# 4               9894   0.4  positive

# %% [markdown]
# ##### Number of comments with neutral sentiment

# %%
# Group neutral sentiment into bins
polarDFnut = EngReviewsDF[['neu']]
polarDFnut = polarDFnut.groupby(pd.cut(polarDFnut["neu"], np.arange(0, 1.1, 0.1))).count()
polarDFnut = polarDFnut.rename(columns={'neu':'count_of_Comments'})
polarDFnut = polarDFnut.reset_index()

# Add RANGE and Sentiment columns
polarDFnut['RANGE'] = polarDFnut['count_of_Comments'].index  # Temporary placeholder, will overwrite next
polarDFnut['RANGE'] = polarDFnut['neu'].apply(lambda x: round(x.left, 2) if pd.notnull(x) else 0)
polarDFnut['Sentiment'] = 'neutral'

# Delete old column
del polarDFnut['neu']

# Append to main polarDF
polarDF = pd.concat([polarDF, polarDFnut], ignore_index=True)

polarDF.head()
# Out:
# C:\Users\kaush\AppData\Local\Temp\ipykernel_20368\3544459875.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   polarDFnut = polarDFnut.groupby(pd.cut(polarDFnut["neu"], np.arange(0, 1.1, 0.1))).count()
#    count_of_Comments RANGE Sentiment
# 0               1653   0.0  positive
# 1              14093   0.1  positive
# 2              29158   0.2  positive
# 3              22304   0.3  positive
# 4               9894   0.4  positive

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Visualizing the sentiment counts
plt.figure(figsize=(12, 6))
sb.catplot(
    data=polarDF,
    x="RANGE",
    y="count_of_Comments",
    col="Sentiment",
    kind="bar",
    height=5,
    aspect=1
)
plt.show()

# %% [markdown]
# From the graphs above, we can conlcude 3 things. First is that **most reviews do not have much negativity. Only a few reviews have a modicum of negativity**. Infact, most of the reviews have no negativity classified in the 0.0 negative sentiment. Second thing we can see is that there are **a lot of reviews with a reasonable amount of positivity**. However, the final thing we can conclude is that **most of the reviews have much neutrality**. **If most of the reviews have a lot of neutrality, we cannot infer much on positivity/negativity of comments with respect to price since the bulk of reviews all fall in the neutral category**. So we can conclude that most reviews are written with a neutral sentiment although there is a very slight tilt to positive sentiments.

# %% [markdown]
# ### Analyzing if number of reviews a listing affects its price.

# %%
inputDF = pd.read_csv('listings.csv')
inputDF=inputDF[['number_of_reviews','price','review_scores_rating']]

# replacing NaN values with 0
inputDF.fillna(0, inplace=True)

#Extracting prices from the table
price = inputDF['price']
prices=[]

#clean the data to make it float
for p in price:
    p=float(p[1:].replace(',',''))
    prices.append(p)

#replace the price column with the new column
inputDF['price']=prices

price_review = inputDF[['number_of_reviews', 'price']].sort_values(by = 'price')

price_review.plot(x = 'price', 
                  y = 'number_of_reviews', 
                  style = 'o',
                  figsize =(12,8),
                  legend = False,
                  title = 'Reviews based on Price')

plt.xlabel("Price")
plt.ylabel("Number of reviews")
# Out:
# Text(0, 0.5, 'Number of reviews')

# %%
sb.heatmap(price_review.corr(), vmin = -1, vmax = 1, linewidths = 1,
           annot = True, fmt = ".2f", annot_kws = {"size": 18}, cmap = "RdBu")
# Out:
# <Axes: >

# %% [markdown]
# From the above correlation matrix, we can clearly see that number of reviews and the price of a listing has a very weak negative correlation. Hence we can conclude that the number of reviews a listing receives does not have much of an impact on the price.

# %% [markdown]
# From all the textual data analysis we have done, we can see that the reviews a listing gets and the number of reviews a listing gets does not have much of an impact on the price of a listing. However, having certain keywords like: 'view', 'modern', 'walk' does put your listing in the same bracket as those listings with higher prices.
